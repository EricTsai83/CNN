# %%
import test_yolo
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
args = test_yolo.parser.parse_known_args()[0]
args.weights_path= 'trained_stage_2_best.h5'#讀取訓練完後的權重
args.test_path = 'test_img'# 將測試資料放於此資料夾
args.output_path = 'test_img/out'# 測試結果輸出資料夾

#args.classes_path = '/data/aia-data/yolo_data/model_data/pascal_classes.txt'#分類的txt檔
args.classes_path = 'own_class.txt'#此行為使用自己的Label的class，上一行為使用'simple_train-comp.ipynb'為Demo的data set

t = test_yolo._main(args)
# Out:
# trained_stage_2_best.h5 model, anchors, and classes loaded.

# %%
t
# Out:
# [(<PIL.PngImagePlugin.PngImageFile image mode=RGB size=572x319 at 0x7F5E88191940>,
#   <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x640 at 0x7F5E67FCAB00>,
#   <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x640 at 0x7F5E67FCABA8>,
#   <PIL.PngImagePlugin.PngImageFile image mode=RGB size=750x1125 at 0x7F5E67FCA978>,
#   <PIL.PngImagePlugin.PngImageFile image mode=RGB size=229x393 at 0x7F5E67FCAC50>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1125x832 at 0x7F5E67FCAC88>,
#   <PIL.PngImagePlugin.PngImageFile image mode=RGB size=319x286 at 0x7F5E67FCA908>,
#   <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x640 at 0x7F5E67FCADA0>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x7F5E67FCA8D0>,
#   <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x640 at 0x7F5E67FCAB70>,
#   <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1200 at 0x7F5E67FCAE80>,
# ...

# %% [markdown]
# ### 如果效果不好沒有抓到物件，到test_yolo.py中，找到以下code，修改'default=.5，調整辨識水平的閥值，降低很容易出現辨識的物件，但同時可能也會有較高的錯誤率
# parser.add_argument(
#     '-s',
#     '--score_threshold',
#     type=float,
#     help='threshold for bounding box scores, default .3',
#     default=.5)

# %%
# 目前 default=.3
t[0][147]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x900 at 0x7F5E67FACA20>
