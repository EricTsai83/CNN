# %%
import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from keras.preprocessing import image
from keras.utils import np_utils, plot_model


import cv2
from glob import glob
from sklearn.utils import shuffle
from time import time


import warnings
warnings.filterwarnings('ignore')
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.xception import Xception
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# 查看類別資寮夾(label)
os.listdir("./training_set")[0:9]
# Out:
# ['akane', 'rika', 'neru', 'yui', '.ipynb_checkpoints', 'risa']

# %%
# 查看類別資料夾裡的資料
os.listdir("./training_set/akane")[0:9]
# Out:
# ['092.png',
#  '073.png',
#  '062.png',
#  '100.png',
#  '055.png',
#  '087.png',
#  '083.png',
#  '082.png',
#  '090.png']

# %%
os.listdir("./testing_set")[0:9]
# Out:
# ['86B9F51B85.png',
#  '65BF2008F2.png',
#  'F1FB9BD260.png',
#  '4318710884.png',
#  'B9CA8A32DF.png',
#  '538CFE6771.png',
#  '40FD801394.png',
#  '27C5695794.png',
#  '8C15F15BFE.png']

# %%
# 類別編碼
pd.read_csv('./classmap.csv')[0:9]
# Out:
#   classname  classnum
# 0      rika         0
# 1      risa         1
# 2       yui         2
# 3     akane         3
# 4      neru         4

# %%
# target_label_file_name = 'classmap.csv'

target_label_file_path = './classmap.csv'
# Opening a file using "with" is as simple as: with open(filename) as file:
# 在 f 資料夾讀一筆，則 .splitlines():返回一個包含各列作為元素的列表，然後 line.split(', ') 代表用 ', ' 分隔相鄰列表
with open(target_label_file_path) as f:
    all_lines = [line.split(',') for line in f.read().splitlines()]
    
all_lines = all_lines[1::]
# 將list 換成dic的形式
target_labels = dict()
for line in all_lines:
    target_class, target_label = line
    target_labels[target_class] = target_label

# %%
target_labels
# Out:
# {'rika': '0', 'risa': '1', 'yui': '2', 'akane': '3', 'neru': '4'}

# %% [markdown]
# # Training Data

# %%
# 指定存放 train 資料集的資料夾
train_dir = "./training_set"
img_path_list = []
img_class_list = []
# 利用迴圈依序用字典的 key 找出該類別(key)的路徑，再透過 glob() 找出路徑下的所有文件，
# 並透過迴圈每找到一個文件，就在 img_class_list 裡增加一個該類的的 label
for key in target_labels.keys():
    for file_path in glob('{}/{}/*.png'.format(train_dir, key)):     # glob: 返回所有匹配的文件路徑列表
        img_class_list.append(target_labels[key])                    # {}.format() : 將()裡的東西，變成{}形式的字串
        img_path_list.append(file_path)

data_list = pd.DataFrame({'class': img_class_list, 'path': img_path_list})

# %%
data_list.head(10)
# Out:
#   class                         path
# 0     0  ./training_set/rika/092.png
# 1     0  ./training_set/rika/073.png
# 2     0  ./training_set/rika/062.png
# 3     0  ./training_set/rika/055.png
# 4     0  ./training_set/rika/087.png
# 5     0  ./training_set/rika/083.png
# 6     0  ./training_set/rika/082.png
# 7     0  ./training_set/rika/090.png
# 8     0  ./training_set/rika/047.png
# 9     0  ./training_set/rika/023.png

# %%
# 改成list 形式 ，才能當 for 迴圈的 index
img_paths_list = data_list['path']
img_labels_list = data_list['class']
train_img_paths, valid_img_paths, y_train, y_valid = train_test_split(img_paths_list, img_labels_list, test_size=0.1)

# %%
print('Some training samples:\n----------------------')
print(train_img_paths.head())

print('\nSome training labels:\n---------------------')
print(y_train.head())

print('\nSome validation samples:\n------------------------')
print(valid_img_paths.head())

print('\nSome validation labels:\n-----------------------')
print(y_valid.head())
# Out:
# Some training samples:
# ----------------------
# 250     ./training_set/yui/009.png
# 24     ./training_set/rika/000.png
# 62     ./training_set/rika/039.png
# 59     ./training_set/rika/085.png
# 502    ./training_set/neru/014.png
# Name: path, dtype: object
#
# Some training labels:
# ---------------------
# 250    2
# 24     0
# 62     0
# 59     0
# 502    4
# Name: class, dtype: object
#
# Some validation samples:
# ------------------------
# 356    ./training_set/akane/048.png
# 234      ./training_set/yui/067.png
# 308      ./training_set/yui/104.png
# 273      ./training_set/yui/010.png
# 231      ./training_set/yui/077.png
# Name: path, dtype: object
#
# Some validation labels:
# -----------------------
# 356    3
# 234    2
# 308    2
# 273    2
# 231    2
# Name: class, dtype: object

# %% [markdown]
# # keras

# %%
num_classes = 5 #label 的類別數
epochs = 100
batch_size = 32

#img_size = 224
img_size = 299

# %%
def load_data(Gray2RGB= False, mean_proc=False, img_size=img_size, test_data = True):
    
#         """ Split the list into training set and validation set """
    
    X_train = []
    for path in train_img_paths:
        img = cv2.imread(path, 0)   # 讀取圖檔，後面的 0 代表讀取圖檔為灰階形式
        img = cv2.resize(img, (img_size, img_size))
        
        if Gray2RGB == True:        # 灰階轉 RGB 檔
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        
        img = img.astype(np.float32) #將圖片轉成數字
            
        # 平均數處理    
        if mean_proc == 'VGG16_ImageNet':
            img = img - np.array([123.68, 116.779, 103.939]) # RGB channel 的平均數(官方給的)
            img = img[:,:,::-1]  # RGB 轉為 BGR， 因為 pre-train 好的 model，channel 為 BGR
            img = (img - np.min(img)) / np.max(img)
        if mean_proc == 'DenseNet':
            img /= 255.
            #img /= 299.
            mean = [0.485, 0.456, 0.406]
            std = [0.229, 0.224, 0.225]
            img = (img - mean) / std
        else:
            img /= 255.
            #img /= 299.
            img -= 0.5
            img *= 2.
            
        X_train.append(img)
    X_train = np.array(X_train, dtype=np.float32)
    
    X_valid = []
    if test_data == True:
        for path in valid_img_paths:
            img = cv2.imread(path, 0)
            img = cv2.resize(img, (img_size, img_size))

            if Gray2RGB == True:
                img = cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)
            
            img = img.astype(np.float32)
            
            if mean_proc == 'VGG16_ImageNet':
                img = img - np.array([123.68, 116.779, 103.939])
                img = img[:,:,::-1]  # RGB to BGR
                img = (img - np.min(img)) / np.max(img)
            if mean_proc == 'DenseNet':
                img /= 255.
                #img /= 299.
                mean = [0.485, 0.456, 0.406]
                std = [0.229, 0.224, 0.225]
                img = (img - mean) / std
            else:
                img /= 255.
                #img /= 299.
                img -= 0.5
                img *= 2.
            X_valid.append(img)
    X_valid = np.array(X_valid, dtype=np.float32)
    
    if Gray2RGB == False:
        X_train = np.reshape(X_train, X_train.shape+(1,))  # .shape+(1,) : 多加一個維度且數目是 1，為了顯示 channel 為一
        X_valid = np.reshape(X_valid, X_valid.shape+(1,))
   
    
    return X_train, X_valid

# %%
X_train, X_valid = load_data(Gray2RGB= True, mean_proc=None, img_size=img_size , test_data = True)

# %%
# one hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes)  #  num_classes: 總類別數
y_valid = tf.keras.utils.to_categorical(y_valid, num_classes)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (484, 299, 299, 3)
# (484, 5)
# (54, 299, 299, 3)
# (54, 5)

# %%
# 創=建一個資料夾，若存在則取消創建
path = 'saved_models'
if not os.path.exists('saved_models'):
    os.mkdir('saved_models')

# %%
model_name = 'Xception-Fine-Tune'

#img_rows, img_cols, img_channel = 224, 224, 3
img_rows, img_cols, img_channel = 299, 299, 3
base_model = Xception(weights='imagenet', include_top=False,
                         input_shape=(img_rows, img_cols, img_channel))

x = base_model.output
x = GlobalAveragePooling2D(data_format='channels_last')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 149, 149, 32) 128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 149, 149, 32) 0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 147, 147, 64) 18432       block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 147, 147, 64) 256         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (Activation)   (None, 147, 147, 64) 0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1 (SeparableConv2 (None, 147, 147, 128 8768        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv1[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_act (Activation (None, 147, 147, 128 0           block2_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2 (SeparableConv2 (None, 147, 147, 128 17536       block2_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormal (None, 147, 147, 128 512         block2_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 74, 74, 128)  8192        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 74, 74, 128)  0           block2_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 74, 74, 128)  512         conv2d[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 74, 74, 128)  0           block2_pool[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_act (Activation (None, 74, 74, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1 (SeparableConv2 (None, 74, 74, 256)  33920       block3_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv1[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_act (Activation (None, 74, 74, 256)  0           block3_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2 (SeparableConv2 (None, 74, 74, 256)  67840       block3_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormal (None, 74, 74, 256)  1024        block3_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 37, 37, 256)  32768       add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 37, 37, 256)  0           block3_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 37, 37, 256)  1024        conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 37, 37, 256)  0           block3_pool[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_act (Activation (None, 37, 37, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1 (SeparableConv2 (None, 37, 37, 728)  188672      block4_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv1[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_act (Activation (None, 37, 37, 728)  0           block4_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2 (SeparableConv2 (None, 37, 37, 728)  536536      block4_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormal (None, 37, 37, 728)  2912        block4_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 19, 19, 728)  186368      add_1[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 19, 19, 728)  0           block4_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 19, 19, 728)  2912        conv2d_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 19, 19, 728)  0           block4_pool[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_act (Activation (None, 19, 19, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv1[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_act (Activation (None, 19, 19, 728)  0           block5_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv2[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_act (Activation (None, 19, 19, 728)  0           block5_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block5_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block5_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 19, 19, 728)  0           block5_sepconv3_bn[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_act (Activation (None, 19, 19, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv1[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_act (Activation (None, 19, 19, 728)  0           block6_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv2[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_act (Activation (None, 19, 19, 728)  0           block6_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block6_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block6_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 19, 19, 728)  0           block6_sepconv3_bn[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_act (Activation (None, 19, 19, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv1[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_act (Activation (None, 19, 19, 728)  0           block7_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv2[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_act (Activation (None, 19, 19, 728)  0           block7_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block7_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block7_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 19, 19, 728)  0           block7_sepconv3_bn[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_act (Activation (None, 19, 19, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv1[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_act (Activation (None, 19, 19, 728)  0           block8_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv2[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_act (Activation (None, 19, 19, 728)  0           block8_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block8_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block8_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 19, 19, 728)  0           block8_sepconv3_bn[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_act (Activation (None, 19, 19, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv1[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_act (Activation (None, 19, 19, 728)  0           block9_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv2[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_act (Activation (None, 19, 19, 728)  0           block9_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3 (SeparableConv2 (None, 19, 19, 728)  536536      block9_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormal (None, 19, 19, 728)  2912        block9_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 19, 19, 728)  0           block9_sepconv3_bn[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv1[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_act (Activatio (None, 19, 19, 728)  0           block10_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv2[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_act (Activatio (None, 19, 19, 728)  0           block10_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block10_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block10_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 19, 19, 728)  0           block10_sepconv3_bn[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv1[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_act (Activatio (None, 19, 19, 728)  0           block11_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv2[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_act (Activatio (None, 19, 19, 728)  0           block11_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block11_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block11_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 19, 19, 728)  0           block11_sepconv3_bn[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv1[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_act (Activatio (None, 19, 19, 728)  0           block12_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv2[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_act (Activatio (None, 19, 19, 728)  0           block12_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3 (SeparableConv (None, 19, 19, 728)  536536      block12_sepconv3_act[0][0]
# __________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNorma (None, 19, 19, 728)  2912        block12_sepconv3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19, 19, 728)  0           block12_sepconv3_bn[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_act (Activatio (None, 19, 19, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1 (SeparableConv (None, 19, 19, 728)  536536      block13_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNorma (None, 19, 19, 728)  2912        block13_sepconv1[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_act (Activatio (None, 19, 19, 728)  0           block13_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2 (SeparableConv (None, 19, 19, 1024) 752024      block13_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNorma (None, 19, 19, 1024) 4096        block13_sepconv2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 10, 10, 1024) 745472      add_10[0][0]
# __________________________________________________________________________________________________
# block13_pool (MaxPooling2D)     (None, 10, 10, 1024) 0           block13_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 10, 10, 1024) 4096        conv2d_3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 10, 10, 1024) 0           block13_pool[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1 (SeparableConv (None, 10, 10, 1536) 1582080     add_11[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNorma (None, 10, 10, 1536) 6144        block14_sepconv1[0][0]
# __________________________________________________________________________________________________
# block14_sepconv1_act (Activatio (None, 10, 10, 1536) 0           block14_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2 (SeparableConv (None, 10, 10, 2048) 3159552     block14_sepconv1_act[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNorma (None, 10, 10, 2048) 8192        block14_sepconv2[0][0]
# __________________________________________________________________________________________________
# block14_sepconv2_act (Activatio (None, 10, 10, 2048) 0           block14_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           block14_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            10245       dropout[0][0]
# ==================================================================================================
# Total params: 20,871,725
# Trainable params: 20,817,197
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
# Data generator with augmentation
## 定義一個產生器，在每看一個batch時，做資料增強，再fit model，實務上這樣做 model 可以看到更多樣的變化，
# 當然如果用事先資料增強的方法，當增強數據越多，結果也會越接近 realtime data augmentation，但儲存空間龐大
datagen = ImageDataGenerator(
    rotation_range=10,        # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,    # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,   # randomly shift images vertically (fraction of total height)
    shear_range=0.2,          
    zoom_range=0.2,
    horizontal_flip=True,    # randomly flip images
    fill_mode='nearest')     # 输入边界以外的点根据给定的模式填充：'constant': kkkkk|abcd|kkkkk (cval=k)                  #                                  'nearest': aaaaaaaa|abcd|dddddddd'
                             #                                  'reflect': abcddcba|abcd|dcbaabcd'wrap'
                             #                                  'wrap': abcdabcd|abcd|abcdabcd
# optimizer = keras.optimizers.Adam(lr=10e-6)
optimizer = keras.optimizers.Adam(lr=10e-7)
# model 存檔的路徑
model_path = './saved_models/{}.h5'.format(model_name)
# 定義要 training 的時候需要記錄下來的結果
# monitor : 要監控的變數
checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)
# 定義 Early stopping 的函數
earlystop = EarlyStopping(monitor='val_loss', patience=10, verbose=1)

model.compile(loss='categorical_crossentropy',
              optimizer=optimizer, metrics=['accuracy'])
# Fit the model on the batches generated by datagen.flow().
batch_size = 16
aug_ratio = 1
#epochs = 200
epochs = 500
steps_per_epoch = int(aug_ratio * X_train.shape[0] / batch_size)
validation_steps = int(aug_ratio * X_valid.shape[0] / batch_size)
# 隨機從每一個 epoch當中抽出圖片做資料增強，然後才吐出 batch 的數量 fit model，但每一個 epoch 的數量不會改變喔
model_history = model.fit_generator(datagen.flow(X_train, y_train, batch_size = batch_size),
                                    epochs = epochs,
                                    validation_data = (X_valid, y_valid),
                                    callbacks = [checkpoint, earlystop],
                                    steps_per_epoch=steps_per_epoch,
                                    validation_steps=validation_steps)
# Out:
# Epoch 1/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.7091 - acc: 0.1853
# Epoch 00001: val_loss improved from inf to 1.66251, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 37s 1s/step - loss: 1.7072 - acc: 0.1877 - val_loss: 1.6625 - val_acc: 0.1852
# Epoch 2/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.7004 - acc: 0.1940
# Epoch 00002: val_loss improved from 1.66251 to 1.65892, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 448ms/step - loss: 1.6997 - acc: 0.1958 - val_loss: 1.6589 - val_acc: 0.1852
# Epoch 3/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6675 - acc: 0.2220
# Epoch 00003: val_loss did not improve from 1.65892
# 30/30 [==============================] - 11s 378ms/step - loss: 1.6657 - acc: 0.2248 - val_loss: 1.6622 - val_acc: 0.1852
# Epoch 4/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6582 - acc: 0.2047
# Epoch 00004: val_loss did not improve from 1.65892
# 30/30 [==============================] - 11s 382ms/step - loss: 1.6636 - acc: 0.2062 - val_loss: 1.6654 - val_acc: 0.1852
# Epoch 5/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6739 - acc: 0.1746
# Epoch 00005: val_loss did not improve from 1.65892
# 30/30 [==============================] - 12s 384ms/step - loss: 1.6717 - acc: 0.1751 - val_loss: 1.6676 - val_acc: 0.1481
# Epoch 6/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6453 - acc: 0.2328
# Epoch 00006: val_loss did not improve from 1.65892
# 30/30 [==============================] - 12s 387ms/step - loss: 1.6471 - acc: 0.2271 - val_loss: 1.6707 - val_acc: 0.1667
# Epoch 7/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6562 - acc: 0.1897
# Epoch 00007: val_loss did not improve from 1.65892
# 30/30 [==============================] - 12s 385ms/step - loss: 1.6558 - acc: 0.1916 - val_loss: 1.6713 - val_acc: 0.1667
# Epoch 8/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6651 - acc: 0.1918
# Epoch 00008: val_loss did not improve from 1.65892
# 30/30 [==============================] - 12s 393ms/step - loss: 1.6640 - acc: 0.2000 - val_loss: 1.6693 - val_acc: 0.1296
# Epoch 9/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6388 - acc: 0.2284
# Epoch 00009: val_loss did not improve from 1.65892
# 30/30 [==============================] - 11s 378ms/step - loss: 1.6380 - acc: 0.2245 - val_loss: 1.6644 - val_acc: 0.1296
# Epoch 10/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6657 - acc: 0.2241
# Epoch 00010: val_loss did not improve from 1.65892
# 30/30 [==============================] - 12s 387ms/step - loss: 1.6685 - acc: 0.2231 - val_loss: 1.6617 - val_acc: 0.1111
# Epoch 11/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6256 - acc: 0.2198
# Epoch 00011: val_loss did not improve from 1.65892
# 30/30 [==============================] - 12s 393ms/step - loss: 1.6231 - acc: 0.2167 - val_loss: 1.6598 - val_acc: 0.1111
# Epoch 12/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6487 - acc: 0.2284
# Epoch 00012: val_loss improved from 1.65892 to 1.65658, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 480ms/step - loss: 1.6479 - acc: 0.2250 - val_loss: 1.6566 - val_acc: 0.1111
# Epoch 13/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6502 - acc: 0.2306
# Epoch 00013: val_loss improved from 1.65658 to 1.65316, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 441ms/step - loss: 1.6465 - acc: 0.2310 - val_loss: 1.6532 - val_acc: 0.1111
# Epoch 14/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6320 - acc: 0.2177
# Epoch 00014: val_loss improved from 1.65316 to 1.64834, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 454ms/step - loss: 1.6319 - acc: 0.2148 - val_loss: 1.6483 - val_acc: 0.1296
# Epoch 15/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6200 - acc: 0.2457
# Epoch 00015: val_loss improved from 1.64834 to 1.64514, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 454ms/step - loss: 1.6211 - acc: 0.2438 - val_loss: 1.6451 - val_acc: 0.1111
# Epoch 16/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6216 - acc: 0.2177
# Epoch 00016: val_loss improved from 1.64514 to 1.64413, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 450ms/step - loss: 1.6227 - acc: 0.2170 - val_loss: 1.6441 - val_acc: 0.1481
# Epoch 17/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6234 - acc: 0.2328
# Epoch 00017: val_loss improved from 1.64413 to 1.64206, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 463ms/step - loss: 1.6268 - acc: 0.2313 - val_loss: 1.6421 - val_acc: 0.1481
# Epoch 18/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6071 - acc: 0.2586
# Epoch 00018: val_loss did not improve from 1.64206
# 30/30 [==============================] - 12s 385ms/step - loss: 1.6040 - acc: 0.2606 - val_loss: 1.6424 - val_acc: 0.1111
# Epoch 19/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6054 - acc: 0.2565
# Epoch 00019: val_loss did not improve from 1.64206
# 30/30 [==============================] - 11s 379ms/step - loss: 1.6020 - acc: 0.2583 - val_loss: 1.6421 - val_acc: 0.1111
# Epoch 20/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6229 - acc: 0.2091
# Epoch 00020: val_loss did not improve from 1.64206
# 30/30 [==============================] - 12s 397ms/step - loss: 1.6278 - acc: 0.2062 - val_loss: 1.6442 - val_acc: 0.1667
# Epoch 21/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6095 - acc: 0.2522
# Epoch 00021: val_loss improved from 1.64206 to 1.64085, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 436ms/step - loss: 1.6088 - acc: 0.2519 - val_loss: 1.6409 - val_acc: 0.1852
# Epoch 22/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5779 - acc: 0.2608
# Epoch 00022: val_loss improved from 1.64085 to 1.63477, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 483ms/step - loss: 1.5829 - acc: 0.2562 - val_loss: 1.6348 - val_acc: 0.2037
# Epoch 23/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5970 - acc: 0.2694
# Epoch 00023: val_loss improved from 1.63477 to 1.62750, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 475ms/step - loss: 1.5995 - acc: 0.2665 - val_loss: 1.6275 - val_acc: 0.2037
# Epoch 24/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5801 - acc: 0.2694
# Epoch 00024: val_loss improved from 1.62750 to 1.62274, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 473ms/step - loss: 1.5801 - acc: 0.2669 - val_loss: 1.6227 - val_acc: 0.2037
# Epoch 25/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6048 - acc: 0.2543
# Epoch 00025: val_loss improved from 1.62274 to 1.61612, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 473ms/step - loss: 1.6030 - acc: 0.2560 - val_loss: 1.6161 - val_acc: 0.2407
# Epoch 26/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5836 - acc: 0.2651
# Epoch 00026: val_loss improved from 1.61612 to 1.61037, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 468ms/step - loss: 1.5855 - acc: 0.2627 - val_loss: 1.6104 - val_acc: 0.2407
# Epoch 27/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5759 - acc: 0.2780
# Epoch 00027: val_loss improved from 1.61037 to 1.60465, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 449ms/step - loss: 1.5713 - acc: 0.2857 - val_loss: 1.6046 - val_acc: 0.2222
# Epoch 28/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.6077 - acc: 0.2759
# Epoch 00028: val_loss improved from 1.60465 to 1.59894, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 431ms/step - loss: 1.6047 - acc: 0.2752 - val_loss: 1.5989 - val_acc: 0.2222
# Epoch 29/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5731 - acc: 0.2608
# Epoch 00029: val_loss improved from 1.59894 to 1.59435, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.5687 - acc: 0.2600 - val_loss: 1.5944 - val_acc: 0.2222
# Epoch 30/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5634 - acc: 0.2780
# Epoch 00030: val_loss improved from 1.59435 to 1.58995, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 15s 486ms/step - loss: 1.5655 - acc: 0.2750 - val_loss: 1.5900 - val_acc: 0.2407
# Epoch 31/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5687 - acc: 0.2737
# Epoch 00031: val_loss improved from 1.58995 to 1.58686, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 449ms/step - loss: 1.5701 - acc: 0.2711 - val_loss: 1.5869 - val_acc: 0.2407
# Epoch 32/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5632 - acc: 0.2866
# Epoch 00032: val_loss improved from 1.58686 to 1.58314, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 459ms/step - loss: 1.5619 - acc: 0.2936 - val_loss: 1.5831 - val_acc: 0.2593
# Epoch 33/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5579 - acc: 0.2996
# Epoch 00033: val_loss improved from 1.58314 to 1.58052, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 464ms/step - loss: 1.5599 - acc: 0.2938 - val_loss: 1.5805 - val_acc: 0.2593
# Epoch 34/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5678 - acc: 0.2845
# Epoch 00034: val_loss improved from 1.58052 to 1.57704, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 451ms/step - loss: 1.5675 - acc: 0.2834 - val_loss: 1.5770 - val_acc: 0.2593
# Epoch 35/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5372 - acc: 0.2845
# Epoch 00035: val_loss improved from 1.57704 to 1.57503, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 448ms/step - loss: 1.5394 - acc: 0.2794 - val_loss: 1.5750 - val_acc: 0.2593
# Epoch 36/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5238 - acc: 0.3190
# Epoch 00036: val_loss improved from 1.57503 to 1.57146, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 455ms/step - loss: 1.5244 - acc: 0.3190 - val_loss: 1.5715 - val_acc: 0.2778
# Epoch 37/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5370 - acc: 0.3125
# Epoch 00037: val_loss improved from 1.57146 to 1.56899, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 15s 487ms/step - loss: 1.5365 - acc: 0.3123 - val_loss: 1.5690 - val_acc: 0.2778
# Epoch 38/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5518 - acc: 0.2888
# Epoch 00038: val_loss improved from 1.56899 to 1.56639, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 483ms/step - loss: 1.5537 - acc: 0.2957 - val_loss: 1.5664 - val_acc: 0.3148
# Epoch 39/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5399 - acc: 0.3125
# Epoch 00039: val_loss improved from 1.56639 to 1.56505, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 438ms/step - loss: 1.5364 - acc: 0.3230 - val_loss: 1.5651 - val_acc: 0.3148
# Epoch 40/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5350 - acc: 0.2823
# Epoch 00040: val_loss improved from 1.56505 to 1.56227, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 454ms/step - loss: 1.5356 - acc: 0.2813 - val_loss: 1.5623 - val_acc: 0.3148
# Epoch 41/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5327 - acc: 0.3470
# Epoch 00041: val_loss improved from 1.56227 to 1.56065, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 473ms/step - loss: 1.5328 - acc: 0.3459 - val_loss: 1.5607 - val_acc: 0.3148
# Epoch 42/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5318 - acc: 0.3168
# Epoch 00042: val_loss improved from 1.56065 to 1.55805, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 452ms/step - loss: 1.5309 - acc: 0.3146 - val_loss: 1.5581 - val_acc: 0.3148
# Epoch 43/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4994 - acc: 0.3384
# Epoch 00043: val_loss improved from 1.55805 to 1.55592, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 439ms/step - loss: 1.5038 - acc: 0.3336 - val_loss: 1.5559 - val_acc: 0.3333
# Epoch 44/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5354 - acc: 0.3060
# Epoch 00044: val_loss improved from 1.55592 to 1.55332, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 447ms/step - loss: 1.5348 - acc: 0.3104 - val_loss: 1.5533 - val_acc: 0.3333
# Epoch 45/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5252 - acc: 0.2974
# Epoch 00045: val_loss improved from 1.55332 to 1.55130, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 437ms/step - loss: 1.5257 - acc: 0.2961 - val_loss: 1.5513 - val_acc: 0.3333
# Epoch 46/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5275 - acc: 0.3384
# Epoch 00046: val_loss improved from 1.55130 to 1.54843, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.5338 - acc: 0.3312 - val_loss: 1.5484 - val_acc: 0.3333
# Epoch 47/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5075 - acc: 0.3276
# Epoch 00047: val_loss improved from 1.54843 to 1.54564, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.5070 - acc: 0.3253 - val_loss: 1.5456 - val_acc: 0.3519
# Epoch 48/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5040 - acc: 0.3405
# Epoch 00048: val_loss improved from 1.54564 to 1.54312, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 15s 484ms/step - loss: 1.5046 - acc: 0.3375 - val_loss: 1.5431 - val_acc: 0.3519
# Epoch 49/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5007 - acc: 0.3879
# Epoch 00049: val_loss improved from 1.54312 to 1.54101, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 465ms/step - loss: 1.5063 - acc: 0.3870 - val_loss: 1.5410 - val_acc: 0.3519
# Epoch 50/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5052 - acc: 0.3664
# Epoch 00050: val_loss improved from 1.54101 to 1.53914, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 475ms/step - loss: 1.5011 - acc: 0.3684 - val_loss: 1.5391 - val_acc: 0.3519
# Epoch 51/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5114 - acc: 0.3254
# Epoch 00051: val_loss improved from 1.53914 to 1.53594, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 473ms/step - loss: 1.5111 - acc: 0.3251 - val_loss: 1.5359 - val_acc: 0.3519
# Epoch 52/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5035 - acc: 0.3642
# Epoch 00052: val_loss improved from 1.53594 to 1.53267, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 457ms/step - loss: 1.5060 - acc: 0.3562 - val_loss: 1.5327 - val_acc: 0.3519
# Epoch 53/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.5157 - acc: 0.3039
# Epoch 00053: val_loss improved from 1.53267 to 1.53041, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 431ms/step - loss: 1.5150 - acc: 0.3063 - val_loss: 1.5304 - val_acc: 0.3519
# Epoch 54/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4786 - acc: 0.4052
# Epoch 00054: val_loss improved from 1.53041 to 1.52814, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 450ms/step - loss: 1.4763 - acc: 0.4042 - val_loss: 1.5281 - val_acc: 0.3704
# Epoch 55/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4926 - acc: 0.3772
# Epoch 00055: val_loss improved from 1.52814 to 1.52551, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 440ms/step - loss: 1.4944 - acc: 0.3772 - val_loss: 1.5255 - val_acc: 0.3889
# Epoch 56/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4854 - acc: 0.3664
# Epoch 00056: val_loss improved from 1.52551 to 1.52318, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.4854 - acc: 0.3624 - val_loss: 1.5232 - val_acc: 0.3889
# Epoch 57/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4924 - acc: 0.3621
# Epoch 00057: val_loss improved from 1.52318 to 1.52046, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 451ms/step - loss: 1.4952 - acc: 0.3582 - val_loss: 1.5205 - val_acc: 0.3889
# Epoch 58/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4681 - acc: 0.3922
# Epoch 00058: val_loss improved from 1.52046 to 1.51857, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 440ms/step - loss: 1.4684 - acc: 0.3937 - val_loss: 1.5186 - val_acc: 0.3889
# Epoch 59/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4672 - acc: 0.4052
# Epoch 00059: val_loss improved from 1.51857 to 1.51583, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 439ms/step - loss: 1.4690 - acc: 0.4020 - val_loss: 1.5158 - val_acc: 0.4074
# Epoch 60/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4745 - acc: 0.3836
# Epoch 00060: val_loss improved from 1.51583 to 1.51333, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 442ms/step - loss: 1.4752 - acc: 0.3816 - val_loss: 1.5133 - val_acc: 0.4259
# Epoch 61/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4890 - acc: 0.3664
# Epoch 00061: val_loss improved from 1.51333 to 1.51014, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 443ms/step - loss: 1.4885 - acc: 0.3624 - val_loss: 1.5101 - val_acc: 0.4259
# Epoch 62/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4090 - acc: 0.4418
# Epoch 00062: val_loss improved from 1.51014 to 1.50764, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 441ms/step - loss: 1.4124 - acc: 0.4370 - val_loss: 1.5076 - val_acc: 0.4444
# Epoch 63/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4625 - acc: 0.3879
# Epoch 00063: val_loss improved from 1.50764 to 1.50475, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 439ms/step - loss: 1.4623 - acc: 0.3872 - val_loss: 1.5047 - val_acc: 0.4444
# Epoch 64/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4695 - acc: 0.3815
# Epoch 00064: val_loss improved from 1.50475 to 1.50230, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.4671 - acc: 0.3857 - val_loss: 1.5023 - val_acc: 0.4444
# Epoch 65/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4481 - acc: 0.3987
# Epoch 00065: val_loss improved from 1.50230 to 1.49979, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.4417 - acc: 0.4062 - val_loss: 1.4998 - val_acc: 0.4259
# Epoch 66/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4390 - acc: 0.4030
# Epoch 00066: val_loss improved from 1.49979 to 1.49676, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 438ms/step - loss: 1.4434 - acc: 0.3980 - val_loss: 1.4968 - val_acc: 0.4259
# Epoch 67/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4365 - acc: 0.3944
# Epoch 00067: val_loss improved from 1.49676 to 1.49411, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.4341 - acc: 0.3960 - val_loss: 1.4941 - val_acc: 0.4259
# Epoch 68/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4292 - acc: 0.4353
# Epoch 00068: val_loss improved from 1.49411 to 1.49072, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 448ms/step - loss: 1.4258 - acc: 0.4396 - val_loss: 1.4907 - val_acc: 0.4630
# Epoch 69/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4571 - acc: 0.3815
# Epoch 00069: val_loss improved from 1.49072 to 1.48816, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.4521 - acc: 0.3815 - val_loss: 1.4882 - val_acc: 0.4444
# Epoch 70/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4441 - acc: 0.4095
# Epoch 00070: val_loss improved from 1.48816 to 1.48427, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 443ms/step - loss: 1.4386 - acc: 0.4125 - val_loss: 1.4843 - val_acc: 0.4630
# Epoch 71/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4120 - acc: 0.4461
# Epoch 00071: val_loss improved from 1.48427 to 1.48095, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 445ms/step - loss: 1.4154 - acc: 0.4397 - val_loss: 1.4809 - val_acc: 0.4630
# Epoch 72/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4398 - acc: 0.4332
# Epoch 00072: val_loss improved from 1.48095 to 1.47844, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 428ms/step - loss: 1.4363 - acc: 0.4336 - val_loss: 1.4784 - val_acc: 0.4815
# Epoch 73/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3783 - acc: 0.4655
# Epoch 00073: val_loss improved from 1.47844 to 1.47464, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 445ms/step - loss: 1.3762 - acc: 0.4667 - val_loss: 1.4746 - val_acc: 0.4815
# Epoch 74/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3914 - acc: 0.4461
# Epoch 00074: val_loss improved from 1.47464 to 1.47271, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 423ms/step - loss: 1.3922 - acc: 0.4437 - val_loss: 1.4727 - val_acc: 0.4815
# Epoch 75/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3680 - acc: 0.4871
# Epoch 00075: val_loss improved from 1.47271 to 1.46998, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.3742 - acc: 0.4791 - val_loss: 1.4700 - val_acc: 0.4815
# Epoch 76/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3992 - acc: 0.4698
# Epoch 00076: val_loss improved from 1.46998 to 1.46667, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 434ms/step - loss: 1.4013 - acc: 0.4664 - val_loss: 1.4667 - val_acc: 0.4815
# Epoch 77/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.4126 - acc: 0.4483
# Epoch 00077: val_loss improved from 1.46667 to 1.46428, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 436ms/step - loss: 1.4119 - acc: 0.4518 - val_loss: 1.4643 - val_acc: 0.5000
# Epoch 78/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3703 - acc: 0.4698
# Epoch 00078: val_loss improved from 1.46428 to 1.46097, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 458ms/step - loss: 1.3724 - acc: 0.4646 - val_loss: 1.4610 - val_acc: 0.5000
# Epoch 79/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3825 - acc: 0.4310
# Epoch 00079: val_loss improved from 1.46097 to 1.45761, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.3883 - acc: 0.4293 - val_loss: 1.4576 - val_acc: 0.5185
# Epoch 80/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3732 - acc: 0.4871
# Epoch 00080: val_loss improved from 1.45761 to 1.45508, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 437ms/step - loss: 1.3764 - acc: 0.4829 - val_loss: 1.4551 - val_acc: 0.5185
# Epoch 81/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3389 - acc: 0.4978
# Epoch 00081: val_loss improved from 1.45508 to 1.45189, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 437ms/step - loss: 1.3406 - acc: 0.4956 - val_loss: 1.4519 - val_acc: 0.5185
# Epoch 82/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3797 - acc: 0.4763
# Epoch 00082: val_loss improved from 1.45189 to 1.44767, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 450ms/step - loss: 1.3830 - acc: 0.4771 - val_loss: 1.4477 - val_acc: 0.5370
# Epoch 83/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3489 - acc: 0.4892
# Epoch 00083: val_loss improved from 1.44767 to 1.44481, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 439ms/step - loss: 1.3527 - acc: 0.4854 - val_loss: 1.4448 - val_acc: 0.5556
# Epoch 84/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3637 - acc: 0.5022
# Epoch 00084: val_loss improved from 1.44481 to 1.44234, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 428ms/step - loss: 1.3671 - acc: 0.4960 - val_loss: 1.4423 - val_acc: 0.5556
# Epoch 85/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3604 - acc: 0.5065
# Epoch 00085: val_loss improved from 1.44234 to 1.43889, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 448ms/step - loss: 1.3600 - acc: 0.5062 - val_loss: 1.4389 - val_acc: 0.5741
# Epoch 86/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3355 - acc: 0.5194
# Epoch 00086: val_loss improved from 1.43889 to 1.43617, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 441ms/step - loss: 1.3334 - acc: 0.5186 - val_loss: 1.4362 - val_acc: 0.5741
# Epoch 87/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3447 - acc: 0.5043
# Epoch 00087: val_loss improved from 1.43617 to 1.43332, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 455ms/step - loss: 1.3461 - acc: 0.5044 - val_loss: 1.4333 - val_acc: 0.5741
# Epoch 88/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3596 - acc: 0.4741
# Epoch 00088: val_loss improved from 1.43332 to 1.43016, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 440ms/step - loss: 1.3574 - acc: 0.4794 - val_loss: 1.4302 - val_acc: 0.5741
# Epoch 89/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3394 - acc: 0.5022
# Epoch 00089: val_loss improved from 1.43016 to 1.42741, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 430ms/step - loss: 1.3403 - acc: 0.5002 - val_loss: 1.4274 - val_acc: 0.5741
# Epoch 90/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3318 - acc: 0.5151
# Epoch 00090: val_loss improved from 1.42741 to 1.42484, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.3311 - acc: 0.5148 - val_loss: 1.4248 - val_acc: 0.5741
# Epoch 91/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3181 - acc: 0.5323
# Epoch 00091: val_loss improved from 1.42484 to 1.42132, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 442ms/step - loss: 1.3208 - acc: 0.5294 - val_loss: 1.4213 - val_acc: 0.5926
# Epoch 92/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3207 - acc: 0.5065
# Epoch 00092: val_loss improved from 1.42132 to 1.41871, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 440ms/step - loss: 1.3165 - acc: 0.5106 - val_loss: 1.4187 - val_acc: 0.5926
# Epoch 93/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3363 - acc: 0.5216
# Epoch 00093: val_loss improved from 1.41871 to 1.41516, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 441ms/step - loss: 1.3383 - acc: 0.5250 - val_loss: 1.4152 - val_acc: 0.5926
# Epoch 94/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3093 - acc: 0.5065
# Epoch 00094: val_loss improved from 1.41516 to 1.41073, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 438ms/step - loss: 1.3091 - acc: 0.5106 - val_loss: 1.4107 - val_acc: 0.5926
# Epoch 95/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2894 - acc: 0.5409
# Epoch 00095: val_loss improved from 1.41073 to 1.40672, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 448ms/step - loss: 1.2873 - acc: 0.5419 - val_loss: 1.4067 - val_acc: 0.5926
# Epoch 96/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3091 - acc: 0.5517
# Epoch 00096: val_loss improved from 1.40672 to 1.40350, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.3059 - acc: 0.5519 - val_loss: 1.4035 - val_acc: 0.6111
# Epoch 97/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3299 - acc: 0.5129
# Epoch 00097: val_loss improved from 1.40350 to 1.40040, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 433ms/step - loss: 1.3353 - acc: 0.5065 - val_loss: 1.4004 - val_acc: 0.6111
# Epoch 98/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3067 - acc: 0.5129
# Epoch 00098: val_loss improved from 1.40040 to 1.39721, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.3104 - acc: 0.5083 - val_loss: 1.3972 - val_acc: 0.5741
# Epoch 99/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2805 - acc: 0.5776
# Epoch 00099: val_loss improved from 1.39721 to 1.39402, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 427ms/step - loss: 1.2826 - acc: 0.5747 - val_loss: 1.3940 - val_acc: 0.5926
# Epoch 100/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.3024 - acc: 0.5237
# Epoch 00100: val_loss improved from 1.39402 to 1.39143, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 437ms/step - loss: 1.3001 - acc: 0.5231 - val_loss: 1.3914 - val_acc: 0.5926
# Epoch 101/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2899 - acc: 0.5259
# Epoch 00101: val_loss improved from 1.39143 to 1.38875, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.2880 - acc: 0.5315 - val_loss: 1.3888 - val_acc: 0.5741
# Epoch 102/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2653 - acc: 0.5733
# Epoch 00102: val_loss improved from 1.38875 to 1.38446, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.2708 - acc: 0.5642 - val_loss: 1.3845 - val_acc: 0.5741
# Epoch 103/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2852 - acc: 0.5409
# Epoch 00103: val_loss improved from 1.38446 to 1.38091, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 455ms/step - loss: 1.2796 - acc: 0.5500 - val_loss: 1.3809 - val_acc: 0.5741
# Epoch 104/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2504 - acc: 0.5496
# Epoch 00104: val_loss improved from 1.38091 to 1.37711, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.2510 - acc: 0.5501 - val_loss: 1.3771 - val_acc: 0.5741
# Epoch 105/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2555 - acc: 0.5668
# Epoch 00105: val_loss improved from 1.37711 to 1.37318, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 456ms/step - loss: 1.2529 - acc: 0.5688 - val_loss: 1.3732 - val_acc: 0.5741
# Epoch 106/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2578 - acc: 0.5711
# Epoch 00106: val_loss improved from 1.37318 to 1.37001, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 427ms/step - loss: 1.2572 - acc: 0.5751 - val_loss: 1.3700 - val_acc: 0.5741
# Epoch 107/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2821 - acc: 0.5582
# Epoch 00107: val_loss improved from 1.37001 to 1.36807, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 433ms/step - loss: 1.2828 - acc: 0.5523 - val_loss: 1.3681 - val_acc: 0.5741
# Epoch 108/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2425 - acc: 0.5453
# Epoch 00108: val_loss improved from 1.36807 to 1.36437, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 447ms/step - loss: 1.2420 - acc: 0.5458 - val_loss: 1.3644 - val_acc: 0.5741
# Epoch 109/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2222 - acc: 0.5819
# Epoch 00109: val_loss improved from 1.36437 to 1.36226, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 439ms/step - loss: 1.2144 - acc: 0.5855 - val_loss: 1.3623 - val_acc: 0.5741
# Epoch 110/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2751 - acc: 0.5496
# Epoch 00110: val_loss improved from 1.36226 to 1.35782, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 429ms/step - loss: 1.2788 - acc: 0.5482 - val_loss: 1.3578 - val_acc: 0.5741
# Epoch 111/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2373 - acc: 0.5754
# Epoch 00111: val_loss improved from 1.35782 to 1.35224, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 447ms/step - loss: 1.2338 - acc: 0.5790 - val_loss: 1.3522 - val_acc: 0.5741
# Epoch 112/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2386 - acc: 0.5841
# Epoch 00112: val_loss improved from 1.35224 to 1.34892, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 454ms/step - loss: 1.2340 - acc: 0.5896 - val_loss: 1.3489 - val_acc: 0.5741
# Epoch 113/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2743 - acc: 0.5345
# Epoch 00113: val_loss improved from 1.34892 to 1.34575, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 429ms/step - loss: 1.2753 - acc: 0.5359 - val_loss: 1.3457 - val_acc: 0.5926
# Epoch 114/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2051 - acc: 0.6099
# Epoch 00114: val_loss improved from 1.34575 to 1.34093, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 470ms/step - loss: 1.2038 - acc: 0.6146 - val_loss: 1.3409 - val_acc: 0.5926
# Epoch 115/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2192 - acc: 0.6034
# Epoch 00115: val_loss improved from 1.34093 to 1.33841, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 442ms/step - loss: 1.2226 - acc: 0.5957 - val_loss: 1.3384 - val_acc: 0.5926
# Epoch 116/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2003 - acc: 0.6164
# Epoch 00116: val_loss improved from 1.33841 to 1.33594, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 439ms/step - loss: 1.1971 - acc: 0.6230 - val_loss: 1.3359 - val_acc: 0.5926
# Epoch 117/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1794 - acc: 0.6401
# Epoch 00117: val_loss improved from 1.33594 to 1.33187, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.1810 - acc: 0.6415 - val_loss: 1.3319 - val_acc: 0.5926
# Epoch 118/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.2308 - acc: 0.5970
# Epoch 00118: val_loss improved from 1.33187 to 1.32707, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.2328 - acc: 0.5958 - val_loss: 1.3271 - val_acc: 0.6111
# Epoch 119/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1970 - acc: 0.5862
# Epoch 00119: val_loss improved from 1.32707 to 1.32183, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 443ms/step - loss: 1.1908 - acc: 0.5940 - val_loss: 1.3218 - val_acc: 0.6296
# Epoch 120/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1642 - acc: 0.6250
# Epoch 00120: val_loss improved from 1.32183 to 1.31798, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 443ms/step - loss: 1.1681 - acc: 0.6209 - val_loss: 1.3180 - val_acc: 0.6111
# Epoch 121/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1933 - acc: 0.6250
# Epoch 00121: val_loss improved from 1.31798 to 1.31530, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 442ms/step - loss: 1.1998 - acc: 0.6188 - val_loss: 1.3153 - val_acc: 0.6296
# Epoch 122/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1783 - acc: 0.6250
# Epoch 00122: val_loss improved from 1.31530 to 1.31108, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 436ms/step - loss: 1.1734 - acc: 0.6272 - val_loss: 1.3111 - val_acc: 0.6481
# Epoch 123/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1517 - acc: 0.6659
# Epoch 00123: val_loss improved from 1.31108 to 1.30818, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 455ms/step - loss: 1.1565 - acc: 0.6624 - val_loss: 1.3082 - val_acc: 0.6481
# Epoch 124/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1652 - acc: 0.6401
# Epoch 00124: val_loss improved from 1.30818 to 1.30538, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 440ms/step - loss: 1.1679 - acc: 0.6397 - val_loss: 1.3054 - val_acc: 0.6481
# Epoch 125/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1621 - acc: 0.6250
# Epoch 00125: val_loss improved from 1.30538 to 1.30193, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 436ms/step - loss: 1.1675 - acc: 0.6232 - val_loss: 1.3019 - val_acc: 0.6481
# Epoch 126/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1442 - acc: 0.6272
# Epoch 00126: val_loss improved from 1.30193 to 1.29817, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.1433 - acc: 0.6272 - val_loss: 1.2982 - val_acc: 0.6481
# Epoch 127/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1876 - acc: 0.5970
# Epoch 00127: val_loss improved from 1.29817 to 1.29387, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 433ms/step - loss: 1.1899 - acc: 0.5957 - val_loss: 1.2939 - val_acc: 0.6481
# Epoch 128/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1330 - acc: 0.6703
# Epoch 00128: val_loss improved from 1.29387 to 1.28921, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 437ms/step - loss: 1.1327 - acc: 0.6685 - val_loss: 1.2892 - val_acc: 0.6481
# Epoch 129/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1416 - acc: 0.6379
# Epoch 00129: val_loss improved from 1.28921 to 1.28581, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 442ms/step - loss: 1.1421 - acc: 0.6418 - val_loss: 1.2858 - val_acc: 0.6481
# Epoch 130/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1289 - acc: 0.6509
# Epoch 00130: val_loss improved from 1.28581 to 1.28161, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.1288 - acc: 0.6539 - val_loss: 1.2816 - val_acc: 0.6481
# Epoch 131/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1234 - acc: 0.6358
# Epoch 00131: val_loss improved from 1.28161 to 1.27783, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.1253 - acc: 0.6314 - val_loss: 1.2778 - val_acc: 0.6481
# Epoch 132/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1307 - acc: 0.6466
# Epoch 00132: val_loss improved from 1.27783 to 1.27432, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 433ms/step - loss: 1.1293 - acc: 0.6482 - val_loss: 1.2743 - val_acc: 0.6481
# Epoch 133/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1242 - acc: 0.6336
# Epoch 00133: val_loss improved from 1.27432 to 1.27085, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 441ms/step - loss: 1.1192 - acc: 0.6357 - val_loss: 1.2708 - val_acc: 0.6667
# Epoch 134/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1039 - acc: 0.6746
# Epoch 00134: val_loss improved from 1.27085 to 1.26461, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 451ms/step - loss: 1.1032 - acc: 0.6771 - val_loss: 1.2646 - val_acc: 0.6667
# Epoch 135/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1328 - acc: 0.6487
# Epoch 00135: val_loss improved from 1.26461 to 1.26234, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 433ms/step - loss: 1.1328 - acc: 0.6482 - val_loss: 1.2623 - val_acc: 0.6852
# Epoch 136/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0974 - acc: 0.6703
# Epoch 00136: val_loss improved from 1.26234 to 1.25881, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 449ms/step - loss: 1.0917 - acc: 0.6792 - val_loss: 1.2588 - val_acc: 0.6852
# Epoch 137/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1191 - acc: 0.6552
# Epoch 00137: val_loss improved from 1.25881 to 1.25616, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 426ms/step - loss: 1.1121 - acc: 0.6563 - val_loss: 1.2562 - val_acc: 0.6852
# Epoch 138/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0825 - acc: 0.6853
# Epoch 00138: val_loss improved from 1.25616 to 1.25157, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 443ms/step - loss: 1.0750 - acc: 0.6875 - val_loss: 1.2516 - val_acc: 0.6852
# Epoch 139/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1155 - acc: 0.6336
# Epoch 00139: val_loss improved from 1.25157 to 1.24661, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 436ms/step - loss: 1.1169 - acc: 0.6294 - val_loss: 1.2466 - val_acc: 0.6852
# Epoch 140/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0583 - acc: 0.7112
# Epoch 00140: val_loss improved from 1.24661 to 1.24328, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 1.0625 - acc: 0.7023 - val_loss: 1.2433 - val_acc: 0.6852
# Epoch 141/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.1187 - acc: 0.6466
# Epoch 00141: val_loss improved from 1.24328 to 1.23823, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 452ms/step - loss: 1.1187 - acc: 0.6438 - val_loss: 1.2382 - val_acc: 0.6852
# Epoch 142/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0522 - acc: 0.6832
# Epoch 00142: val_loss improved from 1.23823 to 1.23372, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 441ms/step - loss: 1.0482 - acc: 0.6854 - val_loss: 1.2337 - val_acc: 0.6852
# Epoch 143/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0873 - acc: 0.6487
# Epoch 00143: val_loss improved from 1.23372 to 1.23155, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 440ms/step - loss: 1.0890 - acc: 0.6441 - val_loss: 1.2316 - val_acc: 0.6852
# Epoch 144/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0681 - acc: 0.7069
# Epoch 00144: val_loss improved from 1.23155 to 1.22596, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 440ms/step - loss: 1.0735 - acc: 0.7020 - val_loss: 1.2260 - val_acc: 0.6852
# Epoch 145/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0444 - acc: 0.6853
# Epoch 00145: val_loss improved from 1.22596 to 1.22343, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 436ms/step - loss: 1.0366 - acc: 0.6922 - val_loss: 1.2234 - val_acc: 0.6852
# Epoch 146/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0588 - acc: 0.6789
# Epoch 00146: val_loss improved from 1.22343 to 1.21952, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 442ms/step - loss: 1.0597 - acc: 0.6812 - val_loss: 1.2195 - val_acc: 0.6852
# Epoch 147/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0752 - acc: 0.6810
# Epoch 00147: val_loss improved from 1.21952 to 1.21666, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 441ms/step - loss: 1.0808 - acc: 0.6749 - val_loss: 1.2167 - val_acc: 0.6852
# Epoch 148/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0352 - acc: 0.7155
# Epoch 00148: val_loss improved from 1.21666 to 1.21255, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 449ms/step - loss: 1.0408 - acc: 0.7104 - val_loss: 1.2125 - val_acc: 0.6852
# Epoch 149/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0200 - acc: 0.7026
# Epoch 00149: val_loss improved from 1.21255 to 1.20973, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 438ms/step - loss: 1.0223 - acc: 0.7023 - val_loss: 1.2097 - val_acc: 0.6852
# Epoch 150/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0493 - acc: 0.6918
# Epoch 00150: val_loss improved from 1.20973 to 1.20612, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 449ms/step - loss: 1.0569 - acc: 0.6816 - val_loss: 1.2061 - val_acc: 0.6852
# Epoch 151/500
# 29/30 [============================>.] - ETA: 0s - loss: 1.0233 - acc: 0.7112
# Epoch 00151: val_loss improved from 1.20612 to 1.20042, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 1.0250 - acc: 0.7083 - val_loss: 1.2004 - val_acc: 0.6852
# Epoch 152/500
# ...
# 29/30 [============================>.] - ETA: 0s - loss: 0.2030 - acc: 0.9547
# Epoch 00414: val_loss improved from 0.67174 to 0.67160, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 439ms/step - loss: 0.2039 - acc: 0.9523 - val_loss: 0.6716 - val_acc: 0.7963
# Epoch 415/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1756 - acc: 0.9806
# Epoch 00415: val_loss did not improve from 0.67160
# 30/30 [==============================] - 12s 396ms/step - loss: 0.1747 - acc: 0.9812 - val_loss: 0.6737 - val_acc: 0.7963
# Epoch 416/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.2359 - acc: 0.9526
# Epoch 00416: val_loss did not improve from 0.67160
# 30/30 [==============================] - 11s 379ms/step - loss: 0.2322 - acc: 0.9545 - val_loss: 0.6744 - val_acc: 0.7963
# Epoch 417/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.2003 - acc: 0.9612
# Epoch 00417: val_loss did not improve from 0.67160
# 30/30 [==============================] - 12s 396ms/step - loss: 0.1980 - acc: 0.9625 - val_loss: 0.6742 - val_acc: 0.7963
# Epoch 418/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1796 - acc: 0.9741
# Epoch 00418: val_loss did not improve from 0.67160
# 30/30 [==============================] - 11s 376ms/step - loss: 0.1768 - acc: 0.9750 - val_loss: 0.6734 - val_acc: 0.7963
# Epoch 419/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1831 - acc: 0.9677
# Epoch 00419: val_loss did not improve from 0.67160
# 30/30 [==============================] - 12s 392ms/step - loss: 0.1805 - acc: 0.9688 - val_loss: 0.6731 - val_acc: 0.7963
# Epoch 420/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1928 - acc: 0.9741
# Epoch 00420: val_loss improved from 0.67160 to 0.66960, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 438ms/step - loss: 0.1917 - acc: 0.9729 - val_loss: 0.6696 - val_acc: 0.7963
# Epoch 421/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1985 - acc: 0.9698
# Epoch 00421: val_loss improved from 0.66960 to 0.66934, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 430ms/step - loss: 0.2002 - acc: 0.9689 - val_loss: 0.6693 - val_acc: 0.7963
# Epoch 422/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1905 - acc: 0.9612
# Epoch 00422: val_loss did not improve from 0.66934
# 30/30 [==============================] - 12s 389ms/step - loss: 0.1909 - acc: 0.9606 - val_loss: 0.6710 - val_acc: 0.7963
# Epoch 423/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.2084 - acc: 0.9612
# Epoch 00423: val_loss improved from 0.66934 to 0.66698, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 437ms/step - loss: 0.2121 - acc: 0.9583 - val_loss: 0.6670 - val_acc: 0.7963
# Epoch 424/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1677 - acc: 0.9849
# Epoch 00424: val_loss did not improve from 0.66698
# 30/30 [==============================] - 11s 382ms/step - loss: 0.1690 - acc: 0.9854 - val_loss: 0.6690 - val_acc: 0.7963
# Epoch 425/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1864 - acc: 0.9698
# Epoch 00425: val_loss did not improve from 0.66698
# 30/30 [==============================] - 12s 391ms/step - loss: 0.1837 - acc: 0.9710 - val_loss: 0.6693 - val_acc: 0.7963
# Epoch 426/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1551 - acc: 0.9806
# Epoch 00426: val_loss did not improve from 0.66698
# 30/30 [==============================] - 12s 396ms/step - loss: 0.1534 - acc: 0.9812 - val_loss: 0.6702 - val_acc: 0.7963
# Epoch 427/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1739 - acc: 0.9720
# Epoch 00427: val_loss did not improve from 0.66698
# 30/30 [==============================] - 12s 386ms/step - loss: 0.1722 - acc: 0.9729 - val_loss: 0.6698 - val_acc: 0.7963
# Epoch 428/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1737 - acc: 0.9763
# Epoch 00428: val_loss did not improve from 0.66698
# 30/30 [==============================] - 12s 392ms/step - loss: 0.1715 - acc: 0.9771 - val_loss: 0.6698 - val_acc: 0.7963
# Epoch 429/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1649 - acc: 0.9784
# Epoch 00429: val_loss did not improve from 0.66698
# 30/30 [==============================] - 12s 389ms/step - loss: 0.1651 - acc: 0.9791 - val_loss: 0.6671 - val_acc: 0.7963
# Epoch 430/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1582 - acc: 0.9806
# Epoch 00430: val_loss improved from 0.66698 to 0.66642, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 438ms/step - loss: 0.1582 - acc: 0.9812 - val_loss: 0.6664 - val_acc: 0.7963
# Epoch 431/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1833 - acc: 0.9720
# Epoch 00431: val_loss did not improve from 0.66642
# 30/30 [==============================] - 12s 387ms/step - loss: 0.1812 - acc: 0.9729 - val_loss: 0.6670 - val_acc: 0.7963
# Epoch 432/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1826 - acc: 0.9828
# Epoch 00432: val_loss did not improve from 0.66642
# 30/30 [==============================] - 12s 388ms/step - loss: 0.1817 - acc: 0.9833 - val_loss: 0.6686 - val_acc: 0.7963
# Epoch 433/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1804 - acc: 0.9720
# Epoch 00433: val_loss did not improve from 0.66642
# 30/30 [==============================] - 12s 386ms/step - loss: 0.1778 - acc: 0.9731 - val_loss: 0.6666 - val_acc: 0.7963
# Epoch 434/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1463 - acc: 0.9892
# Epoch 00434: val_loss improved from 0.66642 to 0.66539, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 0.1476 - acc: 0.9896 - val_loss: 0.6654 - val_acc: 0.7963
# Epoch 435/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1793 - acc: 0.9741
# Epoch 00435: val_loss did not improve from 0.66539
# 30/30 [==============================] - 12s 392ms/step - loss: 0.1751 - acc: 0.9752 - val_loss: 0.6656 - val_acc: 0.7963
# Epoch 436/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1958 - acc: 0.9526
# Epoch 00436: val_loss did not improve from 0.66539
# 30/30 [==============================] - 12s 388ms/step - loss: 0.1965 - acc: 0.9525 - val_loss: 0.6660 - val_acc: 0.7963
# Epoch 437/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1604 - acc: 0.9741
# Epoch 00437: val_loss did not improve from 0.66539
# 30/30 [==============================] - 12s 392ms/step - loss: 0.1594 - acc: 0.9750 - val_loss: 0.6662 - val_acc: 0.7963
# Epoch 438/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1882 - acc: 0.9612
# Epoch 00438: val_loss improved from 0.66539 to 0.66437, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 433ms/step - loss: 0.1858 - acc: 0.9606 - val_loss: 0.6644 - val_acc: 0.7963
# Epoch 439/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1587 - acc: 0.9828
# Epoch 00439: val_loss did not improve from 0.66437
# 30/30 [==============================] - 12s 389ms/step - loss: 0.1577 - acc: 0.9812 - val_loss: 0.6683 - val_acc: 0.7963
# Epoch 440/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.2153 - acc: 0.9461
# Epoch 00440: val_loss improved from 0.66437 to 0.66370, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 455ms/step - loss: 0.2106 - acc: 0.9485 - val_loss: 0.6637 - val_acc: 0.7963
# Epoch 441/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1379 - acc: 0.9849
# Epoch 00441: val_loss did not improve from 0.66370
# 30/30 [==============================] - 12s 386ms/step - loss: 0.1414 - acc: 0.9812 - val_loss: 0.6654 - val_acc: 0.7963
# Epoch 442/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1530 - acc: 0.9806
# Epoch 00442: val_loss did not improve from 0.66370
# 30/30 [==============================] - 12s 385ms/step - loss: 0.1615 - acc: 0.9771 - val_loss: 0.6657 - val_acc: 0.7963
# Epoch 443/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1743 - acc: 0.9784
# Epoch 00443: val_loss did not improve from 0.66370
# 30/30 [==============================] - 12s 386ms/step - loss: 0.1726 - acc: 0.9791 - val_loss: 0.6649 - val_acc: 0.7963
# Epoch 444/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1512 - acc: 0.9741
# Epoch 00444: val_loss did not improve from 0.66370
# 30/30 [==============================] - 12s 395ms/step - loss: 0.1497 - acc: 0.9750 - val_loss: 0.6643 - val_acc: 0.7963
# Epoch 445/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1645 - acc: 0.9784
# Epoch 00445: val_loss did not improve from 0.66370
# 30/30 [==============================] - 11s 378ms/step - loss: 0.1677 - acc: 0.9770 - val_loss: 0.6660 - val_acc: 0.7963
# Epoch 446/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1990 - acc: 0.9612
# Epoch 00446: val_loss did not improve from 0.66370
# 30/30 [==============================] - 12s 388ms/step - loss: 0.1952 - acc: 0.9629 - val_loss: 0.6656 - val_acc: 0.7963
# Epoch 447/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1392 - acc: 0.9871
# Epoch 00447: val_loss did not improve from 0.66370
# 30/30 [==============================] - 12s 389ms/step - loss: 0.1391 - acc: 0.9875 - val_loss: 0.6646 - val_acc: 0.7963
# Epoch 448/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1629 - acc: 0.9806
# Epoch 00448: val_loss did not improve from 0.66370
# 30/30 [==============================] - 12s 386ms/step - loss: 0.1608 - acc: 0.9812 - val_loss: 0.6670 - val_acc: 0.7963
# Epoch 449/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1396 - acc: 0.9806
# Epoch 00449: val_loss improved from 0.66370 to 0.66301, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 451ms/step - loss: 0.1389 - acc: 0.9812 - val_loss: 0.6630 - val_acc: 0.7963
# Epoch 450/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1785 - acc: 0.9634
# Epoch 00450: val_loss improved from 0.66301 to 0.66146, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 443ms/step - loss: 0.1733 - acc: 0.9650 - val_loss: 0.6615 - val_acc: 0.7963
# Epoch 451/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1691 - acc: 0.9698
# Epoch 00451: val_loss improved from 0.66146 to 0.66049, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 435ms/step - loss: 0.1669 - acc: 0.9708 - val_loss: 0.6605 - val_acc: 0.7963
# Epoch 452/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1485 - acc: 0.9914
# Epoch 00452: val_loss did not improve from 0.66049
# 30/30 [==============================] - 12s 384ms/step - loss: 0.1513 - acc: 0.9875 - val_loss: 0.6605 - val_acc: 0.7963
# Epoch 453/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1389 - acc: 0.9806
# Epoch 00453: val_loss improved from 0.66049 to 0.65942, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 14s 450ms/step - loss: 0.1373 - acc: 0.9792 - val_loss: 0.6594 - val_acc: 0.7963
# Epoch 454/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1533 - acc: 0.9763
# Epoch 00454: val_loss did not improve from 0.65942
# 30/30 [==============================] - 12s 386ms/step - loss: 0.1567 - acc: 0.9729 - val_loss: 0.6596 - val_acc: 0.7963
# Epoch 455/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.2000 - acc: 0.9569
# Epoch 00455: val_loss improved from 0.65942 to 0.65841, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 0.2007 - acc: 0.9545 - val_loss: 0.6584 - val_acc: 0.7963
# Epoch 456/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1745 - acc: 0.9655
# Epoch 00456: val_loss improved from 0.65841 to 0.65675, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 443ms/step - loss: 0.1751 - acc: 0.9668 - val_loss: 0.6568 - val_acc: 0.7963
# Epoch 457/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1340 - acc: 0.9828
# Epoch 00457: val_loss did not improve from 0.65675
# 30/30 [==============================] - 12s 387ms/step - loss: 0.1342 - acc: 0.9833 - val_loss: 0.6598 - val_acc: 0.7963
# Epoch 458/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1565 - acc: 0.9763
# Epoch 00458: val_loss did not improve from 0.65675
# 30/30 [==============================] - 12s 386ms/step - loss: 0.1529 - acc: 0.9771 - val_loss: 0.6605 - val_acc: 0.7963
# Epoch 459/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1297 - acc: 0.9763
# Epoch 00459: val_loss did not improve from 0.65675
# 30/30 [==============================] - 12s 385ms/step - loss: 0.1283 - acc: 0.9771 - val_loss: 0.6587 - val_acc: 0.7963
# Epoch 460/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1500 - acc: 0.9763
# Epoch 00460: val_loss improved from 0.65675 to 0.65399, saving model to ./saved_models/Xception-Fine-Tune.h5
# 30/30 [==============================] - 13s 444ms/step - loss: 0.1511 - acc: 0.9731 - val_loss: 0.6540 - val_acc: 0.7963
# Epoch 461/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1457 - acc: 0.9763
# Epoch 00461: val_loss did not improve from 0.65399
# 30/30 [==============================] - 12s 387ms/step - loss: 0.1433 - acc: 0.9773 - val_loss: 0.6578 - val_acc: 0.7963
# Epoch 462/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1226 - acc: 0.9935
# Epoch 00462: val_loss did not improve from 0.65399
# 30/30 [==============================] - 11s 377ms/step - loss: 0.1316 - acc: 0.9856 - val_loss: 0.6588 - val_acc: 0.7963
# Epoch 463/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1393 - acc: 0.9741
# Epoch 00463: val_loss did not improve from 0.65399
# 30/30 [==============================] - 12s 397ms/step - loss: 0.1382 - acc: 0.9750 - val_loss: 0.6593 - val_acc: 0.7963
# Epoch 464/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1675 - acc: 0.9591
# Epoch 00464: val_loss did not improve from 0.65399
# 30/30 [==============================] - 12s 387ms/step - loss: 0.1655 - acc: 0.9608 - val_loss: 0.6610 - val_acc: 0.7963
# Epoch 465/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1429 - acc: 0.9720
# Epoch 00465: val_loss did not improve from 0.65399
# 30/30 [==============================] - 12s 388ms/step - loss: 0.1431 - acc: 0.9731 - val_loss: 0.6633 - val_acc: 0.7963
# Epoch 466/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1517 - acc: 0.9763
# Epoch 00466: val_loss did not improve from 0.65399
# 30/30 [==============================] - 12s 394ms/step - loss: 0.1510 - acc: 0.9771 - val_loss: 0.6641 - val_acc: 0.7963
# Epoch 467/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1636 - acc: 0.9677
# Epoch 00467: val_loss did not improve from 0.65399
# 30/30 [==============================] - 11s 378ms/step - loss: 0.1635 - acc: 0.9668 - val_loss: 0.6609 - val_acc: 0.7963
# Epoch 468/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1473 - acc: 0.9849
# Epoch 00468: val_loss did not improve from 0.65399
# 30/30 [==============================] - 12s 388ms/step - loss: 0.1483 - acc: 0.9854 - val_loss: 0.6587 - val_acc: 0.7963
# Epoch 469/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1374 - acc: 0.9806
# Epoch 00469: val_loss did not improve from 0.65399
# 30/30 [==============================] - 12s 399ms/step - loss: 0.1378 - acc: 0.9812 - val_loss: 0.6597 - val_acc: 0.7963
# Epoch 470/500
# 29/30 [============================>.] - ETA: 0s - loss: 0.1553 - acc: 0.9763
# Epoch 00470: val_loss did not improve from 0.65399
# 30/30 [==============================] - 11s 375ms/step - loss: 0.1529 - acc: 0.9773 - val_loss: 0.6552 - val_acc: 0.7963
# Epoch 00470: early stopping

# %%
training_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.plot(training_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %%
training_acc = model_history.history['acc']
val_acc = model_history.history['val_acc']

plt.plot(training_acc, label="training_acc")
plt.plot(val_acc, label="validation_acc")
plt.xlabel("Epochs")
plt.ylabel("Acc")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Testing Data

# %%
def load_test_data(Gray2RGB=False, mean_proc=False, img_size=img_size):
    img_path_list = []
    #找出 rest data 的路徑
    for img_path in glob('{}/*.png'.format(testset_dir)):
        img_path_list.append(img_path)
        
    X_test = []
    X_id = []
    for path in img_path_list:
        img = cv2.imread(path, 0)
        img = cv2.resize(img, (img_size, img_size))
        
        if Gray2RGB == True:
            img = cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)
        img = img.astype(np.float32)

        if mean_proc == 'VGG16_ImageNet':
            img = img - np.array([123.68, 116.779, 103.939])
            img = img[:,:,::-1]  # RGB to BGR
            img = (img - np.min(img)) / np.max(img)
        if mean_proc == 'DenseNet':
            img /= 255.
            #img /= 299.
            mean = [0.485, 0.456, 0.406]
            std = [0.229, 0.224, 0.225]
            img = (img - mean) / std
        else:
            img /= 255.
            #img /= 299.
            img -= 0.5
            img *= 2.
            
        img_id = path.split('/')[-1].split('.')[0]
        X_test.append(img)
        X_id.append(img_id)
        
    X_test = np.array(X_test, dtype=np.float32)
    
    if Gray2RGB == False:
        X_test = np.reshape(X_test, X_test.shape+(1,))
    
    return X_test, X_id

# %%
# 指定存放 test 資料集的資料夾
testset_dir ="./testing_set"
testset_list = []
test_id_list = []

for img_path in glob('{}/*.png'.format(testset_dir)):
    testset_list.append(img_path)
    id = img_path.split('/')[-1].split('.')[0]  # -1 表示圖片路徑的最後一個 part，也就是圖片名，由於圖片名有加副檔名，
    test_id_list.append(id)                     # 所以用 '.' 做切割，取第0個
testset_df = pd.DataFrame({'id': test_id_list, 'path': testset_list}).sort_values(by='id')

# %%
print('\nSome testing samples:\n------------------------')
print(testset_df.head())
print('\ncomplete path samples:\n------------------------')
print(testset_df['path'][0])
# Out:
# Some testing samples:
# ------------------------
#              id                          path
# 117  006F8606F6  ./testing_set/006F8606F6.png
# 85   00C22FC0EA  ./testing_set/00C22FC0EA.png
# 307  00CECD2708  ./testing_set/00CECD2708.png
# 246  0125D1C6C3  ./testing_set/0125D1C6C3.png
# 127  0158CDF991  ./testing_set/0158CDF991.png
#
# complete path samples:
# ------------------------
# ./testing_set/86B9F51B85.png

# %%
X_test, X_id = load_test_data(Gray2RGB=True, mean_proc=None)

model = load_model(model_path)

scores = model.evaluate(X_valid, y_valid, verbose=1)
print('Validation loss:', scores[0])
print('Validation accuracy:', scores[1])

y_test_pred_prob = model.predict(X_test)
y_test_pred = y_test_pred_prob.argmax(axis=-1)
y_test_pred_df = pd.DataFrame({'id': np.array(X_id), 'class':y_test_pred}).sort_values(by='id')
y_test_pred_df.to_csv('./{}.csv'.format(model_name), index=False)
# Out:
# 54/54 [==============================] - 2s 35ms/step
# Validation loss: 0.6539930778521078
# Validation accuracy: 0.7962962940887168

# %% [markdown]
# # 重起 kernel 後，load 模型，省去之前訓練模型的部分，最後加上以下的code

# %%
# another_model = tf.keras.models.load_model('./saved_models/classic_CNN.h5')

# %%
# X_test, X_id = load_test_data()
# y_test_pred = another_model.predict_classes(X_test)
# y_test_pred_df = pd.DataFrame({'id': np.array(X_id), 'class':y_test_pred}).sort_values(by='id')
# y_test_pred_df.head()
